# %%
import pandas as pd

from  sklearn.cluster import KMeans

from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/titanic data.csv')

# %%
df  = df.drop(columns='PassengerId')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

for i in df.columns:
    df[i] = le.fit_transform(df[i])

# %%
kmeans = KMeans(4)

kmeans.fit(df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, 3, 1, 0, 0, 2, 1, 0, 2, 3, 2, 3, 2, 3, 2, 0, 0, 0, 3, 3,
#        0, 0, 2, 3, 3, 3, 0, 2, 2, 2, 3, 2, 2, 3, 0, 1, 0, 0, 1, 0, 1, 1,
#        3, 2, 2, 0, 0, 1, 0, 2, 1, 3, 0, 0, 2, 0, 2, 1, 0, 3, 1, 0, 2, 0,
#        2, 1, 3, 0, 1, 1, 1, 3, 3, 2, 2, 2, 3, 1, 0, 0, 0, 3, 1, 3, 1, 2,
#        3, 3, 3, 3, 1, 1, 1, 2, 1, 1, 3, 3, 2, 2, 2, 1, 3, 2, 0, 0, 2, 2,
#        0, 0, 3, 1, 3, 2, 1, 0, 1, 3, 1, 2, 0, 0, 2, 0, 2, 2, 0, 3, 1, 1,
#        2, 0, 2, 2, 0, 3, 2, 1, 3, 2, 1, 1, 3, 2, 1, 1, 0, 3, 1, 0, 2, 2,
#        2, 2, 1, 1, 0, 2, 1, 2, 3, 3, 0, 1, 3, 0, 1, 0, 0, 2, 1, 2, 0, 1,
#        2, 1, 3, 2, 2, 2, 3, 3, 0, 0, 2, 0, 1, 2, 0, 3, 1, 0, 1, 2, 2, 2,
#        2, 0, 0, 2, 3, 0, 1, 0, 3, 3, 1, 3, 1, 1, 2, 3, 1, 2, 1, 3, 3, 1,
#        2, 3, 3, 2, 3, 1, 2, 2, 3, 2, 1, 2, 0, 3, 2, 1, 3, 1, 0, 1, 0, 2,
#        1, 2, 3, 0, 2, 3, 3, 3, 2, 0, 0, 2, 2, 0, 2, 3, 2, 0, 2, 3, 0, 3,
#        1, 2, 0, 2, 1, 1, 3, 2, 0, 2, 1, 3, 2, 0, 2, 1, 3, 2, 0, 1, 0, 2,
#        0, 2, 3, 1, 3, 3, 2, 1, 2, 2, 3, 3, 0, 1, 1, 2, 1, 3, 2, 3, 3, 2,
#        1, 1, 3, 2, 0, 1, 1, 2, 3, 0, 2, 0, 1, 1, 0, 3, 2, 2, 0, 3, 1, 3,
#        2, 0, 1, 0, 1, 1, 0, 3, 1, 3, 0, 3, 3, 0, 3, 3, 0, 1, 1, 3, 2, 0,
#        3, 1, 0, 0, 3, 3, 0, 0, 0, 2, 3, 1, 2, 1, 0, 0, 3, 1, 3, 0, 3, 2,
#        2, 2, 1, 0, 3, 1, 1, 0, 2, 3, 2, 1, 1, 3, 2, 2, 3, 1, 3, 2, 2, 1,
#        2, 0, 0, 0, 2, 3, 1, 1, 0, 3, 0, 0, 3, 2, 2, 1, 0, 3, 2, 0, 3, 0,
#        0, 0, 1, 1, 0, 3, 2, 2, 3, 0, 1, 2, 3, 2, 2, 1, 0, 3, 1, 0, 3, 1,
Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# 0           0       2   108    1   28      1      0     523    18    147
# 1           1       0   190    0   51      1      0     596   207     81
# 2           1       2   353    0   34      0      0     669    41    147
# 3           1       0   272    0   47      1      0      49   189     55
# 4           0       2    15    1   47      0      0     472    43    147
# ..        ...     ...   ...  ...  ...    ...    ...     ...   ...    ...
# 886         0       1   548    1   35      0      0     101    85    147
# 887         1       0   303    0   24      0      0      14   153     30
# 888         0       2   413    0   88      1      2     675   131    147
# 889         1       0    81    1   34      0      0       8   153     60
# 890         0       2   220    1   42      0      0     466    30    147
#
#      Embarked  clusters
# 0           2         1
# 1           0         1
# 2           2         1
# 3           2         1
# 4           2         1
# ..        ...       ...
# 886         2         0
# 887         2         1
# 888         2         1
# 889         0         1
# 890         1         1
#
# [891 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def visualize_clusters(cluster_column) :
    '''
    Input - column in all_data dataframe which contains cluster no. for the observations
    '''
     ##start code here
    for_x = all_data['pc1']
    for_y = all_data['pc2']
    sns.scatterplot(x=for_x, y=for_y, hue=cluster_column, 
                data=all_data, s=20);
    plt.legend(loc='lower right');
    ##end code here

# %%
    
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df)

# %%
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2'])

# %%
principalDf
# Out:
#             pc1         pc2
# 0   -316.135255 -222.264393
# 1   -231.667365 -271.234237
# 2    -58.756532 -341.803603
# 3   -202.365192  279.370672
# 4   -413.713274 -178.952358
# ..          ...         ...
# 886   80.153910  243.489371
# 887 -174.840425  315.763934
# 888    0.665506 -335.759899
# 889 -395.784971  298.865726
# 890 -210.137968 -153.991197
#
# [891 rows x 2 columns]

# %%
all_data = pd.concat([ df , principalDf], axis = 1)

# %%
all_data
# Out:
#      Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# 0           0       2   108    1   28      1      0     523    18    147
# 1           1       0   190    0   51      1      0     596   207     81
# 2           1       2   353    0   34      0      0     669    41    147
# 3           1       0   272    0   47      1      0      49   189     55
# 4           0       2    15    1   47      0      0     472    43    147
# ..        ...     ...   ...  ...  ...    ...    ...     ...   ...    ...
# 886         0       1   548    1   35      0      0     101    85    147
# 887         1       0   303    0   24      0      0      14   153     30
# 888         0       2   413    0   88      1      2     675   131    147
# 889         1       0    81    1   34      0      0       8   153     60
# 890         0       2   220    1   42      0      0     466    30    147
#
#      Embarked  clusters         pc1         pc2
# 0           2         1 -316.135255 -222.264393
# 1           0         1 -231.667365 -271.234237
# 2           2         1  -58.756532 -341.803603
# 3           2         3 -202.365192  279.370672
# 4           2         1 -413.713274 -178.952358
# ..        ...       ...         ...         ...
# 886         2         0   80.153910  243.489371
# 887         2         3 -174.840425  315.763934
# 888         2         1    0.665506 -335.759899
# 889         0         3 -395.784971  298.865726
# 890         1         1 -210.137968 -153.991197
#
# [891 rows x 14 columns]

# %%
visualize_clusters('clusters')

# %%
clustering_score = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'random', random_state = 42)
    kmeans.fit(df)
    clustering_score.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
clustering_score
# Out:
# [100960042.3164983,
#  56580128.34739469,
#  38960139.12456754,
#  28721820.24391773,
#  24240747.354276076,
#  20651152.328502398,
#  18403606.823808767,
#  16525906.176657218,
#  14895965.981684007,
#  13778054.35494854]

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1, 11), clustering_score)
plt.scatter(5,clustering_score[4], s = 200, c = 'red', marker='*')
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('Clustering Score')
plt.show()
